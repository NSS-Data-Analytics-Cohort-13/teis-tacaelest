# %%
import pandas as pd

# %%
df_ECO = pd.read_excel('../teis-tacaelest/Data/NSS_ECO Data Ind 3 FFY 2023-24 20241211.xlsx' , sheet_name='ECO with Exit23-24 ')
df_ECO
# Out:
#      DISTRICT  CHILD_ID  Child ID_ Assessement point ECO_Entry_DATE  \
# 0          GN    473991                          NaN     2020-01-07
# 1          GN    474186                          NaN     2020-02-13
# 2          ET    474575                          NaN     2020-01-17
# 3          NW    474623                          NaN     2019-01-22
# 4          SW    474848                          NaN     2021-07-09
# ...       ...       ...                          ...            ...
# 9994       SC    579717                          NaN            NaT
# 9995       SC    579729                          NaN            NaT
# 9996       ET    580243                          NaN            NaT
# 9997       FT    580375                          NaN            NaT
# 9998       MD    580840                          NaN            NaT
#
#       Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  Ent APPROPRIATE_ACTION_SCALE  \
# 0                  1.0                  1.0                           1.0
# ...

# %%
df_bdi3 = pd.read_excel('../teis-tacaelest/Data/NSS data_BDI3 Scores 20230101 20240630_Compiled_20241107.xlsx')
df_bdi3.head()
# Out:
#    Last Name  First Name  Gender  Date of Birth  Location - Root Level (PC)  \
# 0        NaN         NaN     NaN            NaN                         NaN
# 1        NaN         NaN     NaN            NaN                         NaN
# 2        NaN         NaN     NaN            NaN                         NaN
# 3        NaN         NaN     NaN            NaN                         NaN
# 4        NaN         NaN     NaN            NaN                         NaN
#
#          Location - Root Level (AH) Location - Sub Level 1  \
# 0  Tennessee Early Intervention Sys      Greater Nashville
# 1  Tennessee Early Intervention Sys      Greater Nashville
# 2  Tennessee Early Intervention Sys       Upper Cumberland
# 3  Tennessee Early Intervention Sys              Southwest
# 4  Tennessee Early Intervention Sys          South Central
#
#    Location - Sub Level 2  Location - Sub Level 3 Child ID  ...  \
# 0                     NaN                     NaN   474074  ...
# ...

# %%
df_bdi2 = pd.read_csv('../teis-tacaelest/Data/NSS data_BDI2 scores_20200101-20230131_20241106.csv',low_memory=False)
df_bdi2.head()
# Out:
#    StudentID  studentAssessmentID  resultStudentDomainID Student TEIDS ID  \
# 0    2224693              8625078              138104116            52101
# 1    2224693              8625078              138104117            52101
# 2    2224693              8625078              138104118            52101
# 3    2224693              8625078              138104119            52101
# 4    2224693              8625078              138104120            52101
#
#    domainID                    domainText  ScoreTypeID ScoreTypeText  \
# 0         7                     Self-Care          2.0   ItemDetails
# 1        10             Adult Interaction          2.0   ItemDetails
# 2        12  Self-Concept and Social Role          2.0   ItemDetails
# 3        14       Receptive Communication          2.0   ItemDetails
# 4        15      Expressive Communication          2.0   ItemDetails
#
#    StaffExternalID   testDate  ... AESign  isSSRequired  stdDevScore1  \
# ...

# %%
df_bdi2_basic = df_bdi2[['Student TEIDS ID','testDate','lastUpdateDate','DQScore']]
type(df_bdi2_basic)
# Out:
# pandas.core.frame.DataFrame

# %%
df_bdi2_swap = df_bdi2[['domainText','Student TEIDS ID','testDate','lastUpdateDate','rawScore','DQScore','ZScore']].transpose()
df_bdi2_swap
# Out:
#                      0                  1                             2       \
# domainText        Self-Care  Adult Interaction  Self-Concept and Social Role
# Student TEIDS ID      52101              52101                         52101
# testDate          2/25/2022          2/25/2022                     2/25/2022
# lastUpdateDate          NaN                NaN                           NaN
# rawScore                2.0               14.0                           6.0
# DQScore                 NaN                NaN                           NaN
# ZScore                -1.33               1.67                          0.33
#
#                                    3                         4       \
# domainText        Receptive Communication  Expressive Communication
# Student TEIDS ID                    52101                     52101
# testDate                        2/25/2022                 2/25/2022
# lastUpdateDate                        NaN                       NaN
# ...

# %%
df_domain = df_bdi2[['rawScore', 'scaledScore', 'PRScore', 'ZScore', 'AEScore', 'TScore', 'NceScore']].transpose()
df_domain
# Out:
#              0       1       2       3       4       5       6       7       \
# rawScore       2.00   14.00    6.00    4.00     1.0    5.00     5.0    6.00
# scaledScore    6.00   15.00   11.00    6.00     4.0    8.00    10.0    9.00
# PRScore        9.00   95.00   63.00    9.00     2.0   25.00    50.0   37.00
# ZScore        -1.33    1.67    0.33   -1.33    -2.0   -0.67     0.0   -0.33
# AEScore        0.00    5.00    2.00    0.00     0.0    0.00     2.0    1.00
# TScore        37.00   67.00   53.00   37.00    30.0   43.00    50.0   47.00
# NceScore      22.00   85.00   57.00   22.00     8.0   36.00    50.0   43.00
#
#              8       9       ...  325676  325677  325678  325679  325680  \
# rawScore        5.0    2.00  ...   12.00   17.00     NaN   39.00     NaN
# scaledScore    10.0    6.00  ...    9.00    2.00     NaN   13.00     NaN
# PRScore        50.0    9.00  ...   37.00    0.40     NaN   13.00     NaN
# ...

# %%
#domain/subdomain scores: RS, SS, PR, Z-Score, AE, RDI, CSS, CSS 90%, T-Score, NCE
# RS = 'rawScore'  SS = 'scaledScore' , PR = 'PRScore' , Z-Score = 'ZScore' , AE = 'AEScore' , T-Score = 'TScore' , NCE = 'NceScore'
# Not Found: RDI, CSS, CSS 90%, 
#RDI may not be available bc it could be solely available to BDI-3
